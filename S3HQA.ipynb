# %%
# !git clone https://github.com/lfy79001/s3hqa.git
# Out:
# Cloning into 's3hqa'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 85 (delta 45), reused 49 (delta 19), pack-reused 0
# Receiving objects: 100% (85/85), 33.24 KiB | 4.16 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
# %cd s3hqa
# Out:
# /content/s3hqa

# %%
# !pip install torch==1.11.0
# !pip install transformers==4.21.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.6/750.6 MB 2.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.0+cu121
#     Uninstalling torch-2.3.0+cu121:
#       Successfully uninstalled torch-2.3.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.3.0+cu121 requires torch==2.3.0, but you have torch 1.11.0 which is incompatible.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 1.11.0 which is incompatible.
# torchvision 0.18.0+cu121 requires torch==2.3.0, but you have torch 1.11.0 which is incompatible.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 45.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 69.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
# ...

# %%
# Install necessary libraries
# !pip install gdown

# Download the Data.zip file
# !gdown --id 1aVoBWvAE2BBaO5a27xHpgOqKGWzUV0K5 -O /content/Data.zip

# Unzip the Data.zip file
# !unzip /content/Data.zip -d /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Data/HybridQA/WikiTables-WithLinks/tables_tok/Live_with_Regis_and_Kelly_(season_21)_5.json
#   inflating: /content/Data/HybridQA/WikiTables-WithLinks/tables_tok/List_of_Lambda_Chi_Alpha_brothers_4.json
#   inflating: /content/Data/HybridQA/WikiTables-WithLinks/tables_tok/Kim_Stanley_0.json
#   inflating: /content/Data/HybridQA/WikiTables-WithLinks/tables_tok/List_of_United_States_national_ice_hockey_team_rosters_5.json
#   inflating: /content/Data/HybridQA/WikiTables-WithLinks/tables_tok/List_of_soccer_clubs_in_Australia_13.json
#   inflating: /content/Data/HybridQA/WikiTables-WithLinks/tables_tok/List_of_Presbyterian_churches_in_the_United_States_33.json
#   inflating: /content/Data/HybridQA/WikiTables-WithLinks/tables_tok/Population_decline_0.json
#   inflating: /content/Data/HybridQA/WikiTables-WithLinks/tables_tok/List_of_German_dishes_7.json
# ...

# %%
# Download the generation_best.zip file
# !gdown --id 1IWHY-_kLNyHKZBxenX-RDBwDwqjiD2Zg -O /content/generation_best.zip

# Unzip the generation_best.zip file
# !unzip /content/generation_best.zip -d /content/
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1IWHY-_kLNyHKZBxenX-RDBwDwqjiD2Zg
# From (redirected): https://drive.google.com/uc?id=1IWHY-_kLNyHKZBxenX-RDBwDwqjiD2Zg&confirm=t&uuid=d12cf3ba-4565-4dcc-8f89-00598c20cbd8
# To: /content/generation_best.zip
# 100% 1.51G/1.51G [00:38<00:00, 39.2MB/s]
# Archive:  /content/generation_best.zip
#    creating: /content/generation_best/
#   inflating: /content/__MACOSX/._generation_best
#   inflating: /content/generation_best/ckpt.pt

# %%
# !pip install torch transformers

# %%
from transformers import AutoModel, AutoTokenizer

# Define the models and their respective directories
models = {
    "bert-base-uncased": "./PTM/bert-base-uncased",
    "microsoft/deberta-base": "./PTM/deberta-base",
    "facebook/bart-large": "./PTM/bart-large"
}

for model_name, directory in models.items():
    # Load the model and tokenizer
    model = AutoModel.from_pretrained(model_name)
    tokenizer = AutoTokenizer.from_pretrained(model_name)

    # Save the model and tokenizer to the specified directory
    model.save_pretrained(directory)
    tokenizer.save_pretrained(directory)

    print(f"Downloaded and saved {model_name} to {directory}")
# Out:
# ...
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...
# Downloaded and saved bert-base-uncased to ./PTM/bert-base-uncased
# ...

# %%
import json

# Load the JSON files
with open('/content/s3hqa/Data/HybridQA/train.row.json', 'r') as f:
    train_data = json.load(f)

with open('/content/s3hqa/Data/HybridQA/dev.row.json', 'r') as f:
    dev_data = json.load(f)

with open('/content/s3hqa/Data/HybridQA/test.row.json', 'r') as f:
    test_data = json.load(f)

# Function to preprocess the data if needed
def preprocess(data):
    # Implement any preprocessing steps here if required
    return data

# Preprocess the data
train_data = preprocess(train_data)
dev_data = preprocess(dev_data)
test_data = preprocess(test_data)

# Example function to use the data for training a reader model
def train_reader_model(train_data, dev_data, test_data):
    # Implement your training logic here
    pass

# Train the reader model using the provided data
train_reader_model(train_data, dev_data, test_data)

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# Run the script
# !bash read_dev.sh
# Out:
# 2024-06-08 14:01:57.899146: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-08 14:01:57.899217: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-08 14:01:57.907383: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-08 14:02:00.076295: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 06/08/2024 02:02:01 is_train=0, is_test=0, lr=1e-05, epoch_num=10, output_dir=generation_best, load_dir=generation_best, bert_max_length=1024
# ...
